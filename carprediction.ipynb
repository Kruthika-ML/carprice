# %%
import pandas as pd

# %%
df = pd.read_csv('car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df['Owner'].unique()
# Out:
# array([0, 1, 3])

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_df = df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_df['Current_Year'] = 2020

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2020
# 1       Manual      0          2020
# 2       Manual      0          2020
# 3       Manual      0          2020
# 4       Manual      0          2020

# %%
final_df['no_years'] = final_df['Current_Year'] - final_df['Year']

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  no_years
# 0       Manual      0          2020         6
# 1       Manual      0          2020         7
# 2       Manual      0          2020         3
# 3       Manual      0          2020         9
# 4       Manual      0          2020         6

# %%
final_df.drop(['Year'],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  no_years
# 0       Manual      0          2020         6
# 1       Manual      0          2020         7
# 2       Manual      0          2020         3
# 3       Manual      0          2020         9
# 4       Manual      0          2020         6

# %%
final_df.drop(['Current_Year'],axis=1,inplace=True)

# %%
final_df = pd.get_dummies(final_df,drop_first=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no_years  \
# 0           3.35           5.59       27000      0         6
# 1           4.75           9.54       43000      0         7
# 2           7.25           9.85        6900      0         3
# 3           2.85           4.15        5200      0         9
# 4           4.60           6.87       42450      0         6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Selling_Price           301 non-null    float64
#  1   Present_Price           301 non-null    float64
#  2   Kms_Driven              301 non-null    int64
#  3   Owner                   301 non-null    int64
#  4   no_years                301 non-null    int64
#  5   Fuel_Type_Diesel        301 non-null    uint8
#  6   Fuel_Type_Petrol        301 non-null    uint8
#  7   Seller_Type_Individual  301 non-null    uint8
#  8   Transmission_Manual     301 non-null    uint8
# dtypes: float64(2), int64(3), uint8(4)
# memory usage: 13.1 KB

# %%
import seaborn as sns

# %%
sns.pairplot(final_df)

# %%
corrmat = final_df.corr()

# %%
top_corr_features = corrmat.index

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))

# %%
ax,fig = plt.subplots(figsize=(17,8))
sns.heatmap(final_df.corr(),annot=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no_years  \
# 0           3.35           5.59       27000      0         6
# 1           4.75           9.54       43000      0         7
# 2           7.25           9.85        6900      0         3
# 3           2.85           4.15        5200      0         9
# 4           4.60           6.87       42450      0         6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
X = final_df.drop('Selling_Price',axis=1)
y = final_df['Selling_Price']

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTree

# %%
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([0.35297474, 0.03855592, 0.00047631, 0.07407984, 0.25116615,
#        0.00483185, 0.13386325, 0.14405194])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_random = RandomForestRegressor()

# %%
rf_random.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_random.score(X_test,y_test)
# Out:
# 0.8680271213111399

# %%
y_preds = rf_random.predict(X_train)

# %%
y_preds
# Out:
# array([19.365 ,  6.764 ,  1.2071,  8.602 ,  2.142 ,  0.4552,  2.387 ,
#         5.199 ,  6.9645,  4.9755,  4.4725,  4.5346,  0.1774,  3.5555,
#         5.543 ,  2.902 ,  1.526 , 13.6062,  4.3175,  0.5374,  5.4095,
#         6.783 ,  0.5625,  2.2305,  5.1275,  2.8035,  0.5805,  1.1232,
#         5.633 ,  0.4544,  2.8525,  1.0425,  0.2269,  1.6645,  6.0395,
#         2.579 ,  0.5586,  0.5776,  3.762 , 11.4981, 10.1098,  2.735 ,
#         6.947 ,  8.906 ,  0.5851,  0.571 ,  5.651 ,  5.0375, 11.061 ,
#         3.0245,  8.651 ,  3.0745,  5.6185,  3.9855,  0.4739,  9.5935,
#         7.4065,  3.946 ,  5.3115,  1.432 ,  2.171 ,  6.3999,  5.167 ,
#         0.6188,  5.3195,  5.138 , 10.29  ,  5.252 ,  0.6885,  1.5885,
#         3.1288,  2.993 ,  6.85  ,  8.468 ,  0.3848,  5.9445,  0.7475,
#         0.1484, 16.1508,  4.1205,  1.1791,  3.9575,  0.4557,  1.0715,
#         4.3907,  0.2268,  0.2677,  0.8204,  4.8425,  3.993 , 11.5917,
#         2.8795,  1.1958,  4.7455,  7.0515,  2.871 , 10.836 ,  4.82  ,
#         9.2545,  4.9305,  7.3639,  6.4615,  0.4496,  0.6566,  7.819 ,
#         5.37  ,  8.162 ,  5.882 ,  0.5961,  0.4157,  0.1861,  0.268 ,
#         4.2225,  9.5805,  0.1834,  0.3974,  2.498 ,  5.427 ,  0.6061,
#         4.5345, 20.5436,  0.4915,  6.2895,  5.887 ,  5.2265,  6.006 ,
#         6.687 ,  4.534 , 16.1185,  5.1775,  0.5526,  2.1795,  1.195 ,
#         1.162 ,  1.1177,  3.8935,  5.63  ,  4.1684,  4.2595,  3.0955,
#         8.8948,  3.1645,  1.352 ,  0.4666,  5.6   ,  3.11  ,  1.1102,
#         7.4855,  4.177 ,  1.1641,  1.409 ,  5.3365,  3.0055,  3.4915,
#         3.993 ,  3.687 ,  5.123 ,  1.681 ,  0.3522, 15.1445,  4.585 ,
#         0.4671,  2.787 ,  7.7359,  0.3605,  5.8095,  0.4602,  0.9496,
#         9.4672,  0.249 ,  1.1389,  1.0568,  0.2659,  0.1823,  7.0785,
#         3.7043,  2.4455,  4.068 ,  0.6174,  2.288 ,  0.2652,  5.219 ,
#         2.8435,  0.3926,  4.9395,  0.6187,  6.1675,  5.262 , 22.773 ,
#         0.7443,  0.4725,  0.527 ,  2.7515,  4.9445,  4.206 ,  3.4481,
#         2.811 ,  4.728 , 15.0495,  7.3145,  5.7225, 14.2339,  6.563 ,
#        23.36  ,  2.66  ,  3.325 ,  0.4471,  2.3884,  0.3592,  7.0725,
#         0.725 ,  8.5055,  1.175 ,  3.649 ,  7.9198,  4.7475,  0.4079,
#         0.2757,  7.222 ,  1.7757,  5.629 ,  4.949 ,  5.818 ,  7.3001,
#         4.3505,  7.7359, 10.4601,  6.5235,  7.7305,  0.4809,  0.2741,
#        22.773 ,  0.618 ,  0.3998,  2.5625,  2.8635,  4.1665,  5.119 ,
#        29.0425,  8.9172])

# %%
import pickle
file = open('random_forest_regression_model.pkl','wb')
pickle.dump(rf_random, file)
